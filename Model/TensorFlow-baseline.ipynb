# %% [markdown]
# baseline思路：使用CNN进行定长字符分类；
#
# 运行系统要求：Python2/3，内存4G，有无GPU都可以

# %%
import numpy as np
import pandas as pd
import os
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import cv2
import json
import glob

# %%
def seed_everything(seed=0):
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'

SEED = 2048
seed_everything(SEED)
BATCH_SIZE = 32
EPOCHS = 20
IMG_HEIGHT, IMG_WIDTH = 64, 128

AUTOTUNE = tf.data.experimental.AUTOTUNE

# %%
def label_map(x):
    for i in range(4):
        x.append(10)
    return x[:5]

# %%
data_root = os.path.expanduser("~/NumReg/")
train_path = glob.glob(data_root+'train/*.png')
train_path.sort()
train_json = json.load(open(data_root+'train.json'))
train_label = [train_json[x]['label'] for x in train_json]
train_label = np.array(list(map(label_map, train_label)))
n_train = len(train_path)
STEPS_PER_EPOCH = n_train//BATCH_SIZE

val_path = glob.glob(data_root+'val/*.png')
val_path.sort()
val_json = json.load(open(data_root+'val.json'))
val_label = [val_json[x]['label'] for x in val_json]
val_label = np.array(list(map(label_map, val_label)))

# %%
train_label[:,0]
# Out:
# array([1, 2, 2, ..., 2, 1, 3])

# %%
def decode_image(filename, label=None, image_size=(IMG_HEIGHT, IMG_WIDTH)):
    bits = tf.io.read_file(filename)
    image = tf.image.decode_png(bits, channels=3)
    image = tf.image.convert_image_dtype(image, tf.float32)
    image = tf.image.resize(image, image_size)
    
    if label is None:
        return image
    else:
        
        return image, label

def data_augment(image, label=None):
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    image = tf.image.rot90(image, tf.random.uniform(shape=[], minval=0, maxval=4, dtype=tf.int32))
    image = tf.image.random_brightness(image, max_delta=0.05)
    #image = tf.image.random_contrast(image, 0.7, 1.3)
    image = tf.clip_by_value(image, clip_value_min=0., clip_value_max=1.)
    if label is None:
        return image
    else:
        return image, label

# %%
train_dataset = (
tf.data.Dataset
    .from_tensor_slices((train_path, (train_label[:,0], train_label[:,1], train_label[:,2], train_label[:,3], train_label[:,4])))
    .map(decode_image, num_parallel_calls=AUTOTUNE)
    .cache()
    #.map(data_augment, num_parallel_calls=AUTOTUNE)
    .repeat()
    .shuffle(512)
    .batch(BATCH_SIZE)
    .prefetch(AUTOTUNE)
)
valid_dataset = (
    tf.data.Dataset
    .from_tensor_slices((val_path, (val_label[:,0], val_label[:,1], val_label[:,2], val_label[:,3], val_label[:,4])))
    .map(decode_image, num_parallel_calls=AUTOTUNE)
    .batch(BATCH_SIZE)
    .cache()
    .prefetch(AUTOTUNE)
)

# %%
def plotImages(images_arr, labels):
    row = min(len(labels) // 5 + 1, 5)
    fig, axes = plt.subplots(row, 5, figsize=(10,8))
    axes = axes.flatten()
    for img, ax, la in zip( images_arr, axes, labels):
        ax.imshow(img)
        ax.set_title(str(la))
        #ax.axis('off')
    plt.tight_layout()
    plt.show()
#####Virtualize the images
for image_batch, label_batch in valid_dataset.take(1):
    plotImages(image_batch.numpy(), label_batch[0].numpy())

# %%
basemodel = keras.applications.ResNet50V2(
    include_top=False, weights='imagenet', input_shape=(IMG_HEIGHT, IMG_WIDTH,3)
)
x = basemodel.output
pool = layers.Flatten()(x)
out1 = layers.Dense(11, name='o1')(pool)
out2 = layers.Dense(11, name='o2')(pool)
out3 = layers.Dense(11, name='o3')(pool)
out4 = layers.Dense(11, name='o4')(pool)
out5 = layers.Dense(11, name='o5')(pool)
model = keras.Model(inputs=basemodel.input,
                    outputs=[out1, out2, out3, out4, out5])

# %%
model.summary()
model.compile(optimizer= 'adam',
              loss=[keras.losses.CategoricalCrossentropy(from_logits=True),
                    keras.losses.CategoricalCrossentropy(from_logits=True),
                    keras.losses.CategoricalCrossentropy(from_logits=True),
                    keras.losses.CategoricalCrossentropy(from_logits=True),
                    keras.losses.CategoricalCrossentropy(from_logits=True)],
              loss_weights=[1, 1, 1, 1, 1],
              metrics=['accuracy'])
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 128, 3)] 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 70, 134, 3)   0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 32, 64, 64)   9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 34, 66, 64)   0           conv1_conv[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 16, 32, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_preact_bn (BatchNo (None, 16, 32, 64)   256         pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_preact_relu (Activ (None, 16, 32, 64)   0           conv2_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 16, 32, 64)   4096        conv2_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 16, 32, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 16, 32, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_pad (ZeroPadding (None, 18, 34, 64)   0           conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 16, 32, 64)   36864       conv2_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 16, 32, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 16, 32, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 16, 32, 256)  16640       conv2_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 16, 32, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Add)          (None, 16, 32, 256)  0           conv2_block1_0_conv[0][0]
#                                                                  conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_preact_bn (BatchNo (None, 16, 32, 256)  1024        conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_preact_relu (Activ (None, 16, 32, 256)  0           conv2_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 16, 32, 64)   16384       conv2_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 16, 32, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 16, 32, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_pad (ZeroPadding (None, 18, 34, 64)   0           conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 16, 32, 64)   36864       conv2_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 16, 32, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 16, 32, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 16, 32, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Add)          (None, 16, 32, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_preact_bn (BatchNo (None, 16, 32, 256)  1024        conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_preact_relu (Activ (None, 16, 32, 256)  0           conv2_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 16, 32, 64)   16384       conv2_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 16, 32, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 16, 32, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_pad (ZeroPadding (None, 18, 34, 64)   0           conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 8, 16, 64)    36864       conv2_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 8, 16, 64)    256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 8, 16, 64)    0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 8, 16, 256)   0           conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 8, 16, 256)   16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Add)          (None, 8, 16, 256)   0           max_pooling2d[0][0]
#                                                                  conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_preact_bn (BatchNo (None, 8, 16, 256)   1024        conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_preact_relu (Activ (None, 8, 16, 256)   0           conv3_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 8, 16, 128)   32768       conv3_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 8, 16, 128)   512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 8, 16, 128)   0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_pad (ZeroPadding (None, 10, 18, 128)  0           conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 8, 16, 128)   147456      conv3_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 8, 16, 128)   512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 8, 16, 128)   0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 8, 16, 512)   131584      conv3_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 8, 16, 512)   66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Add)          (None, 8, 16, 512)   0           conv3_block1_0_conv[0][0]
#                                                                  conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_preact_bn (BatchNo (None, 8, 16, 512)   2048        conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_preact_relu (Activ (None, 8, 16, 512)   0           conv3_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 8, 16, 128)   65536       conv3_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 8, 16, 128)   512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 8, 16, 128)   0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_pad (ZeroPadding (None, 10, 18, 128)  0           conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 8, 16, 128)   147456      conv3_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 8, 16, 128)   512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 8, 16, 128)   0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 8, 16, 512)   66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Add)          (None, 8, 16, 512)   0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_preact_bn (BatchNo (None, 8, 16, 512)   2048        conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_preact_relu (Activ (None, 8, 16, 512)   0           conv3_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 8, 16, 128)   65536       conv3_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 8, 16, 128)   512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 8, 16, 128)   0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_pad (ZeroPadding (None, 10, 18, 128)  0           conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 8, 16, 128)   147456      conv3_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 8, 16, 128)   512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 8, 16, 128)   0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 8, 16, 512)   66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Add)          (None, 8, 16, 512)   0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_preact_bn (BatchNo (None, 8, 16, 512)   2048        conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_preact_relu (Activ (None, 8, 16, 512)   0           conv3_block4_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 8, 16, 128)   65536       conv3_block4_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 8, 16, 128)   512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 8, 16, 128)   0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_pad (ZeroPadding (None, 10, 18, 128)  0           conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 4, 8, 128)    147456      conv3_block4_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 4, 8, 128)    512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 4, 8, 128)    0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 4, 8, 512)    0           conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 4, 8, 512)    66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Add)          (None, 4, 8, 512)    0           max_pooling2d_1[0][0]
#                                                                  conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_preact_bn (BatchNo (None, 4, 8, 512)    2048        conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_preact_relu (Activ (None, 4, 8, 512)    0           conv4_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 4, 8, 256)    131072      conv4_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 4, 8, 256)    1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 4, 8, 256)    0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_pad (ZeroPadding (None, 6, 10, 256)   0           conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 4, 8, 256)    589824      conv4_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 4, 8, 256)    1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 4, 8, 256)    0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 4, 8, 1024)   525312      conv4_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 4, 8, 1024)   263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Add)          (None, 4, 8, 1024)   0           conv4_block1_0_conv[0][0]
#                                                                  conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_preact_bn (BatchNo (None, 4, 8, 1024)   4096        conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_preact_relu (Activ (None, 4, 8, 1024)   0           conv4_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 4, 8, 256)    262144      conv4_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 4, 8, 256)    1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 4, 8, 256)    0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_pad (ZeroPadding (None, 6, 10, 256)   0           conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 4, 8, 256)    589824      conv4_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 4, 8, 256)    1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 4, 8, 256)    0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 4, 8, 1024)   263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Add)          (None, 4, 8, 1024)   0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_preact_bn (BatchNo (None, 4, 8, 1024)   4096        conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_preact_relu (Activ (None, 4, 8, 1024)   0           conv4_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 4, 8, 256)    262144      conv4_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 4, 8, 256)    1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 4, 8, 256)    0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_pad (ZeroPadding (None, 6, 10, 256)   0           conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 4, 8, 256)    589824      conv4_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 4, 8, 256)    1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 4, 8, 256)    0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 4, 8, 1024)   263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Add)          (None, 4, 8, 1024)   0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_preact_bn (BatchNo (None, 4, 8, 1024)   4096        conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_preact_relu (Activ (None, 4, 8, 1024)   0           conv4_block4_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 4, 8, 256)    262144      conv4_block4_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 4, 8, 256)    1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 4, 8, 256)    0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_pad (ZeroPadding (None, 6, 10, 256)   0           conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 4, 8, 256)    589824      conv4_block4_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 4, 8, 256)    1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 4, 8, 256)    0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 4, 8, 1024)   263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Add)          (None, 4, 8, 1024)   0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_preact_bn (BatchNo (None, 4, 8, 1024)   4096        conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_preact_relu (Activ (None, 4, 8, 1024)   0           conv4_block5_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 4, 8, 256)    262144      conv4_block5_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 4, 8, 256)    1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 4, 8, 256)    0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_pad (ZeroPadding (None, 6, 10, 256)   0           conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 4, 8, 256)    589824      conv4_block5_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 4, 8, 256)    1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 4, 8, 256)    0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 4, 8, 1024)   263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Add)          (None, 4, 8, 1024)   0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_preact_bn (BatchNo (None, 4, 8, 1024)   4096        conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_preact_relu (Activ (None, 4, 8, 1024)   0           conv4_block6_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 4, 8, 256)    262144      conv4_block6_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 4, 8, 256)    1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 4, 8, 256)    0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_pad (ZeroPadding (None, 6, 10, 256)   0           conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 2, 4, 256)    589824      conv4_block6_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 2, 4, 256)    1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 2, 4, 256)    0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 2, 4, 1024)   0           conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 2, 4, 1024)   263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Add)          (None, 2, 4, 1024)   0           max_pooling2d_2[0][0]
#                                                                  conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_preact_bn (BatchNo (None, 2, 4, 1024)   4096        conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_preact_relu (Activ (None, 2, 4, 1024)   0           conv5_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 2, 4, 512)    524288      conv5_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 2, 4, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 2, 4, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_pad (ZeroPadding (None, 4, 6, 512)    0           conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 2, 4, 512)    2359296     conv5_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 2, 4, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 2, 4, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 2, 4, 2048)   2099200     conv5_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 2, 4, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Add)          (None, 2, 4, 2048)   0           conv5_block1_0_conv[0][0]
#                                                                  conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_preact_bn (BatchNo (None, 2, 4, 2048)   8192        conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_preact_relu (Activ (None, 2, 4, 2048)   0           conv5_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 2, 4, 512)    1048576     conv5_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 2, 4, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 2, 4, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_pad (ZeroPadding (None, 4, 6, 512)    0           conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 2, 4, 512)    2359296     conv5_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 2, 4, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 2, 4, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 2, 4, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Add)          (None, 2, 4, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_preact_bn (BatchNo (None, 2, 4, 2048)   8192        conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_preact_relu (Activ (None, 2, 4, 2048)   0           conv5_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 2, 4, 512)    1048576     conv5_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 2, 4, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 2, 4, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_pad (ZeroPadding (None, 4, 6, 512)    0           conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 2, 4, 512)    2359296     conv5_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 2, 4, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 2, 4, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 2, 4, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Add)          (None, 2, 4, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# post_bn (BatchNormalization)    (None, 2, 4, 2048)   8192        conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# post_relu (Activation)          (None, 2, 4, 2048)   0           post_bn[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 16384)        0           post_relu[0][0]
# __________________________________________________________________________________________________
# o1 (Dense)                      (None, 11)           180235      flatten[0][0]
# __________________________________________________________________________________________________
# o2 (Dense)                      (None, 11)           180235      flatten[0][0]
# __________________________________________________________________________________________________
# o3 (Dense)                      (None, 11)           180235      flatten[0][0]
# __________________________________________________________________________________________________
# o4 (Dense)                      (None, 11)           180235      flatten[0][0]
# __________________________________________________________________________________________________
# o5 (Dense)                      (None, 11)           180235      flatten[0][0]
# ==================================================================================================
# Total params: 24,465,975
# Trainable params: 24,420,535
# Non-trainable params: 45,440
# __________________________________________________________________________________________________

# %%
history = model.fit(
    train_dataset, 
    epochs=EPOCHS, 
    #callbacks=[lr_callback],
    steps_per_epoch=STEPS_PER_EPOCH,
    validation_data=valid_dataset
)
# Out:
# Train for 937 steps, validate for 313 steps
# Epoch 1/20
# 937/937 [==============================] - 74s 79ms/step - loss: 1781.1127 - o1_loss: 121.1765 - o2_loss: 163.3038 - o3_loss: 419.9737 - o4_loss: 622.9973 - o5_loss: 453.6618 - o1_accuracy: 0.0019 - o2_accuracy: 0.0218 - o3_accuracy: 4.3356e-04 - o4_accuracy: 0.6503 - o5_accuracy: 0.0011 - val_loss: 26065.4379 - val_o1_loss: 2060.9219 - val_o2_loss: 4920.1382 - val_o3_loss: 4340.3047 - val_o4_loss: 4941.7578 - val_o5_loss: 9802.3115 - val_o1_accuracy: 0.7594 - val_o2_accuracy: 8.0000e-04 - val_o3_accuracy: 1.0000e-04 - val_o4_accuracy: 0.1051 - val_o5_accuracy: 0.0000e+00
# Epoch 2/20
# 937/937 [==============================] - 63s 67ms/step - loss: 1784.6924 - o1_loss: 118.9489 - o2_loss: 154.5145 - o3_loss: 380.2085 - o4_loss: 624.5311 - o5_loss: 506.4898 - o1_accuracy: 0.0025 - o2_accuracy: 0.0442 - o3_accuracy: 0.0000e+00 - o4_accuracy: 0.9004 - o5_accuracy: 0.0016 - val_loss: 1960.9786 - val_o1_loss: 186.3279 - val_o2_loss: 175.3401 - val_o3_loss: 464.8003 - val_o4_loss: 625.0031 - val_o5_loss: 509.5072 - val_o1_accuracy: 0.0000e+00 - val_o2_accuracy: 0.0000e+00 - val_o3_accuracy: 0.0000e+00 - val_o4_accuracy: 1.0000 - val_o5_accuracy: 0.0000e+0015 - o1_accuracy: 0.0041 - o2_accuracy: 0.0919 - o3_accuracy: 0. - ETA: 40s - loss: 1864.2752 - o1_loss: 117.7919 - o2_loss: 154.3678 - o3_loss: 402.1717 - o4_loss: 682.4962 - o5_loss: 507.4474 - o1_accuracy: 0.0047 - o2_accuracy: 0.0927 - o3_accuracy: 0.0000e+00 - o4_accuracy: 0.7492 - o5_accu - ETA: 39s - loss: 1865.5389 - o1_loss: 118.2434 - o2_loss: 154.3785 - o3_loss: 401.8387 - o4_loss: 683.4941 - o5_loss: 507.5839 - o1_accuracy: 0.0046 - o2_accuracy: 0.0928 - o3_accuracy: 0.0000e+00 - o4_accuracy: 0.7502 - o5_accu - ETA: 39s - loss: 1867.3037 - o1_loss: 118.4382 - o2_loss: 154.7444 - o3_loss: 401.6218 - o4_loss: 684.5928 - o5_loss: 507.9063 - o1_accuracy: 0.0044 - o2_accuracy: 0.0933 - o3_accu - ETA: 35s - loss: 1863.9602 - o1_loss: 118.1688 - o2_loss: 155.8570 - o3_loss: 396.9094 - o4_loss: 684.3982 - o5_loss: 508.6267 - o1_accuracy: 0.0042 - o2_accuracy: 0.0815 - o3_accuracy: 0.0000e+00 - o4_accuracy: - ETA: 33s - loss: 1862.1321 - o1_loss: 118.2892 - o2_loss: 156.4277 - o3_loss: 395.115 - ETA: 24s - loss: 1860.3794 - o1_loss: 121.0057 - o2_loss: 155.9645 - o3_loss: 393.8644 - o4_loss: 678.6096 - o5_loss: 510.9350 - o1_accuracy: 0.0042 - o2_accuracy: 0.0604 - o3_accuracy: 0.0000e+00 - o4_accuracy: 0.8 - ETA: 22s - loss: 1859.1030 - o1_loss: 121.4028 - o2_loss: 156.2592 - o3_loss: 393.4340 - o4_loss: 676.6890 - o5_loss: 511.3179 - o1_accuracy: 0.0042 - o2_accuracy: 0.0621 - o3_accur - ETA: 19s - loss: 1848.8942 - o1_loss: 121.2938 - o2_loss: 156.1725 - o3_loss: 391.1068 - o4_loss: 668.7718 - o5_loss: 511.5495 - o1_accuracy: 0.0038 - o2_accurac - ETA: 14s - loss: 1831.9778 - o1_loss: 120.7319 - o2_loss: 155.9052 - o3_loss: 387.7814 - o4_loss: 656.8765 - o5_loss: 510.6828 - o1_accuracy: 0.0034 - o2_accuracy: 0.0557 - o3_accuracy: 0.0000e+00 - o4_accuracy: 0. - ETA: 12s - loss: 1825.5873 - o1_loss: 120.3321 - o2_loss: 155.9551 - o3_loss: 386.2899 - o4_loss: 652.7106 - o5_loss: 510.2997 - o1_accuracy: 0.0033 - o2_accuracy: 0.0549 - o3_accuracy: 0.0000e+00 - o - ETA: 10s - loss: 1816.7726 - o1_loss: 120.2141 - o2_loss: 155.9074 - o3_loss: 384.6529 - o4_loss: 646.3651 - o5_loss: 509.6332 - o1_accuracy: 0.0031 - o2_accuracy: 0.0538 - o3_accuracy: 0.0000e+00 - o4_accuracy: 0.8787 - o5_accuracy: 0.001 - ETA: 10s - loss: 1816.5584 - o1_loss: 120.2044 - o2_loss: 155.9010 - o3_loss: 384.6106 - o4_loss: 646.2272 - o5_loss: 509.6154 - o1_accuracy:  - ETA: 7s - loss: 1806.7534 - o1_loss: 119.6992 - o2_loss: 155.3547 - o3_loss: 383.4857 - o4_loss: 639.5023 - o5_loss: 508.7119 - o1_accuracy: 0.0029 - o2_accuracy: 0.0504 - o3_accuracy: 0.0000e+00 - - ETA: 5s - loss: 1803.4131 - o1_loss: 119.7562 - o2_loss: 155.2655 - o3_loss: 383.2443 - o - ETA: 1s - loss: 1788.5520 - o1_loss: 119.1129 - o2_loss: 154.4721 - o3_loss: 380.9680 - o4_loss: 627.1360 - o5_loss: 506.8635 - o1_accuracy: 0.0026 - o2_accuracy: 0.0451 - o3_accuracy: 0.0000e+00 - o4_accuracy: 0.8982 - o5_accuracy: 0.00 - ETA: 1s - loss: 1788.3261 - o1_loss: 119.1127 - o2_loss: 154.4521 - o3_loss: 380.9135 - o4_loss: 627.0035 - o5_loss: 506.8447 - o1_accuracy: 0.0026 - o2_accuracy: 0.0451 - o3_accuracy: 0.0000e+00 - o4_
# Epoch 3/20
# 277/937 [=======>......................] - ETA: 40s - loss: 1623.6368 - o1_loss: 111.6180 - o2_loss: 150.9100 - o3_loss: 353.9043 - o4_loss: 521.0294 - o5_loss: 486.1751 - o1_accuracy: 0.0000e+00 - o2_accuracy: 0.0015 - o3_accuracy: 0.0000e+00 - o4_accuracy: 0.9992 - o5_accuracy: 0.0000e+00    - ETA: 53s - loss: 1604.8413 - o1_loss: 108.6566 - o2_loss: 147.5483 - o3_loss: 346.7189 - o4_loss: 513.2550 - o5_loss: 488.6623 - o1_accuracy: 0.0000e+00 - o2_accuracy: 4.2808e-04 - o3_accuracy: 0.0000e+00 - o4_accuracy: 1.0000 - o5_accuracy: 0.0000e+0 - ETA: 53s - loss: 1605.5518 - o1_loss: 109.1021 - o2_loss: 147.6191 - o3_loss: 346.8364 - o4_loss: 513.3522 - o5_loss: 488.6418 - o1_accuracy: 0.0000e+00 - o2_accuracy: 4.2230e-04 - o3_accuracy: 0.0000e+00 - o4_acc - ETA: 50s - loss: 1611.2330 - o1_loss: 110.9113 - o2_loss: 149.6293 - o3_loss: 347.6909 - o4_loss: 514.6524 - o5_loss: 488.3490 - o1_accuracy: 0.0000e+00 - o2_accuracy: 2.7655e-04 - o3_accuracy: 0.0000e+00 - o4_accuracy: 1.0000 - o5_accuracy: 0.0000e+0 - ETA: 50s - loss: 1610.8734 - o1_loss: 110.7682 - o2_loss: 149.5831 - o3_loss: 347.4124 - o4_loss: 514.7721 - o5_loss: 488.3375 - o1_accuracy: 0.0000e+00 - o2_accuracy: 2.7412e-04 - o3_accuracy: 0.0000e+00 - o4_accuracy: 1.0000 - o5_accura - ETA: 49s - loss: 1611.0471 - o1_loss: 111.0760 - o2_loss: 150.3287 - o3_loss: 347.2581 - o4_loss: 514.3101 - o5_loss: 488.0743 - o1_accuracy: 0.0000e+00 - o2_accuracy: 2.4414e-04 - o3_accuracy: 0.0000e+00 - o4_acc - ETA: 47s - loss: 1610.7145 - o1_loss: 112.0158 - o2_loss: 151.1028 - o3_loss: 345.9010 - o4_loss: 514.2611 - o5_loss: 487.4336 - o1_accuracy: 0.0000e+00 - o2_accuracy: 9.3563e-04 - o3_accuracy: 0.0000e+00 - o4_accuracy: 1.0000 - o5_ac - ETA: 46s - loss: 1612.1933 - o1_loss: 111.1299 - o2_loss: 150.3753 - o3_loss: 347.8614 - o4_loss: 515.5262 - o5_loss: 487.3003 - o1_accuracy: 0.0000e+00 - o2_accuracy: 0.00 - ETA: 41s - loss: 1622.1942 - o1_loss: 111.5601 - o2_loss: 150.7116 - o3_loss: 353.4174 - o4_loss: 520.1984 - o5_loss: 486.3069 - o1_accuracy: 0.0000e+00 - o2_accuracy: 0.0014 - o3_accuracy: 0.0000e+00 - o4_accuracy: 0.9992 - o5_accu

# %% [markdown]
# # 定义读取数据集

# %%
class SVHNDataset(Dataset):
    def __init__(self, img_path, img_label, transform=None):
        self.img_path = img_path
        self.img_label = img_label 
        if transform is not None:
            self.transform = transform
        else:
            self.transform = None

    def __getitem__(self, index):
        img = Image.open(self.img_path[index]).convert('RGB')

        if self.transform is not None:
            img = self.transform(img)
        
        lbl = np.array(self.img_label[index], dtype=np.int)
        lbl = list(lbl)  + (5 - len(lbl)) * [10]
        return img, torch.from_numpy(np.array(lbl[:5]))

    def __len__(self):
        return len(self.img_path)

# %% [markdown]
# # 定义读取数据dataloader
#
# 假设数据存放在`../input`文件夹下，并进行解压。

# %%
data_root = os.path.expanduser("~/NumReg/")
train_path = glob.glob(data_root+'train/*.png')
train_path.sort()
train_json = json.load(open(data_root+'train.json'))
train_label = [train_json[x]['label'] for x in train_json]
print(len(train_path), len(train_label))

train_loader = torch.utils.data.DataLoader(
    SVHNDataset(train_path, train_label,
                transforms.Compose([
                    transforms.Resize((64, 128)),
                    transforms.RandomCrop((60, 120)),
                    transforms.ColorJitter(0.3, 0.3, 0.2),
                    transforms.RandomRotation(10),
                    transforms.ToTensor(),
                    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])), 
    batch_size=20, 
    shuffle=True
)

val_path = glob.glob(data_root+'val/*.png')
val_path.sort()
val_json = json.load(open(data_root+'val.json'))
val_label = [val_json[x]['label'] for x in val_json]
print(len(val_path), len(val_label))

val_loader = torch.utils.data.DataLoader(
    SVHNDataset(val_path, val_label,
                transforms.Compose([
                    transforms.Resize((60, 120)),
                    # transforms.ColorJitter(0.3, 0.3, 0.2),
                    # transforms.RandomRotation(5),
                    transforms.ToTensor(),
                    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])), 
    batch_size=40, 
    shuffle=False
)
# Out:
# 30000 30000
# 10000 10000

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.figure(figsize=(15,20))
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(train_loader))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out)

# %%
num_ftrs = model_ft.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.fc = nn.Linear(num_ftrs, 2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-7f857ba7dac2> in <module>
# ----> 1 num_ftrs = model_ft.fc.in_features
#       2 # Here the size of each output sample is set to 2.
#       3 # Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
#       4 model_ft.fc = nn.Linear(num_ftrs, 2)
#
# NameError: name 'model_ft' is not defined

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %% [markdown]
# # 定义分类模型
#
# 这里使用ResNet18的模型进行特征提取

# %%
class SVHN_Model1(nn.Module):
    def __init__(self):
        super(SVHN_Model1, self).__init__()
                
        model_conv = models.resnet18(pretrained=True)
        model_conv.avgpool = nn.AdaptiveAvgPool2d(1)
        model_conv = nn.Sequential(*list(model_conv.children())[:-1])
        self.cnn = model_conv
        
        self.fc1 = nn.Linear(512, 11)
        self.fc2 = nn.Linear(512, 11)
        self.fc3 = nn.Linear(512, 11)
        self.fc4 = nn.Linear(512, 11)
        self.fc5 = nn.Linear(512, 11)
    
    def forward(self, img):        
        feat = self.cnn(img)
        # print(feat.shape)
        feat = feat.view(feat.shape[0], -1)
        c1 = self.fc1(feat)
        c2 = self.fc2(feat)
        c3 = self.fc3(feat)
        c4 = self.fc4(feat)
        c5 = self.fc5(feat)
        return c1, c2, c3, c4, c5

# %%
def train(train_loader, model, criterion, optimizer, epoch):
    # 切换模型为训练模式
    model.train()
    train_loss = []
    preds_for_acc = []
    labels_for_acc = []
    pbar = tqdm(total = len(train_loader), desc='Training')
    for i, (input, target) in enumerate(train_loader):
        if use_cuda:
            input = input.cuda()
            target = target.cuda()
            
        c0, c1, c2, c3, c4 = model(input)
        target=target.long()
        loss = criterion(c0, target[:, 0]) + \
                criterion(c1, target[:, 1]) + \
                criterion(c2, target[:, 2]) + \
                criterion(c3, target[:, 3]) + \
                criterion(c4, target[:, 4])
        
        # loss /= 6
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        #labels_for_acc = np.concatenate((labels_for_acc, labels.cpu().numpy()), 0)
        #preds_for_acc = np.concatenate((preds_for_acc, np.argmax(predictions.cpu().detach().numpy(), 1)), 0)
        train_loss.append(loss.item())
        pbar.update()
    
    #accuracy = accuracy_score(labels_for_acc, preds_for_acc)
    pbar.close()
    
    return np.mean(train_loss)

def validate(val_loader, model, criterion):
    # 切换模型为预测模型
    model.eval()
    val_loss = []

    # 不记录模型梯度信息
    with torch.no_grad():
        for i, (input, target) in enumerate(val_loader):
            if use_cuda:
                input = input.cuda()
                target = target.cuda()
            
            c0, c1, c2, c3, c4 = model(input)
            target=target.long()
            loss = criterion(c0, target[:, 0]) + \
                    criterion(c1, target[:, 1]) + \
                    criterion(c2, target[:, 2]) + \
                    criterion(c3, target[:, 3]) + \
                    criterion(c4, target[:, 4])
            # loss /= 6
            val_loss.append(loss.item())
    return np.mean(val_loss)

def predict(test_loader, model, tta=10):
    model.eval()
    test_pred_tta = None
    
    # TTA 次数
    for _ in range(tta):
        test_pred = []
    
        with torch.no_grad():
            for i, (input, target) in enumerate(test_loader):
                if use_cuda:
                    input = input.cuda()
                
                c0, c1, c2, c3, c4 = model(input)
                if use_cuda:
                    output = np.concatenate([
                        c0.data.cpu().numpy(), 
                        c1.data.cpu().numpy(),
                        c2.data.cpu().numpy(), 
                        c3.data.cpu().numpy(),
                        c4.data.cpu().numpy()], axis=1)
                else:
                    output = np.concatenate([
                        c0.data.numpy(), 
                        c1.data.numpy(),
                        c2.data.numpy(), 
                        c3.data.numpy(),
                        c4.data.numpy()], axis=1)
                
                test_pred.append(output)
        
        test_pred = np.vstack(test_pred)
        if test_pred_tta is None:
            test_pred_tta = test_pred
        else:
            test_pred_tta += test_pred
    
    return test_pred_tta

# %% [markdown]
# # 训练与验证

# %%
model = SVHN_Model1()
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), 0.001)
best_loss = 1000.0

use_cuda = True
if use_cuda:
    model = model.cuda()

for epoch in range(10):
    train_loss = train(train_loader, model, criterion, optimizer, epoch)
    val_loss = validate(val_loader, model, criterion)
    
    val_label = [''.join(map(str, x)) for x in val_loader.dataset.img_label]
    val_predict_label = predict(val_loader, model, 1)
    val_predict_label = np.vstack([
        val_predict_label[:, :11].argmax(1),
        val_predict_label[:, 11:22].argmax(1),
        val_predict_label[:, 22:33].argmax(1),
        val_predict_label[:, 33:44].argmax(1),
        val_predict_label[:, 44:55].argmax(1),
    ]).T
    val_label_pred = []
    for x in val_predict_label:
        val_label_pred.append(''.join(map(str, x[x!=10])))
    
    val_char_acc = np.mean(np.array(val_label_pred) == np.array(val_label))
    
    print('Epoch: {0}, Train loss: {1} \t Val loss: {2}'.format(epoch, train_loss, val_loss))
    print('Val Acc', val_char_acc)
    # 记录下验证集精度
    if val_loss < best_loss:
        best_loss = val_loss
        # print('Find better model in Epoch {0}, saving model.'.format(epoch))
        #torch.save(model.state_dict(), './model.pt')

# %% [markdown]
# # 预测并生成提交文件

# %%
test_path = glob.glob('../input/test_a/*.png')
test_path.sort()
test_json = json.load(open('../input/test_a.json'))
test_label = [[1]] * len(test_path)
print(len(test_path), len(test_label))

test_loader = torch.utils.data.DataLoader(
    SVHNDataset(test_path, test_label,
                transforms.Compose([
                    transforms.Resize((70, 140)),
                    # transforms.RandomCrop((60, 120)),
                    # transforms.ColorJitter(0.3, 0.3, 0.2),
                    # transforms.RandomRotation(5),
                    transforms.ToTensor(),
                    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])), 
    batch_size=40, 
    shuffle=False, 
    num_workers=10,
)

# %%
# 加载保存的最优模型
model.load_state_dict(torch.load('model.pt'))

test_predict_label = predict(test_loader, model, 1)
print(test_predict_label.shape)

test_label = [''.join(map(str, x)) for x in test_loader.dataset.img_label]
test_predict_label = np.vstack([
    test_predict_label[:, :11].argmax(1),
    test_predict_label[:, 11:22].argmax(1),
    test_predict_label[:, 22:33].argmax(1),
    test_predict_label[:, 33:44].argmax(1),
    test_predict_label[:, 44:55].argmax(1),
]).T

test_label_pred = []
for x in test_predict_label:
    test_label_pred.append(''.join(map(str, x[x!=10])))
    
import pandas as pd
df_submit = pd.read_csv('../input/test_A_sample_submit.csv')
df_submit['file_code'] = test_label_pred
df_submit.to_csv('submit.csv', index=None)
